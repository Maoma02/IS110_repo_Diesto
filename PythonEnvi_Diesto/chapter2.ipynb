# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.name 'Maria Angela Rey Diesto' #your full name
# !git config --global user.email 'ma.angelarey.diesto@students.isatu.edu.ph'

# %%
# !git clone https://Maoma02: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@github.com/Maoma02/IS110_repo_MDiesto.git
# Out:
# Cloning into 'IS110_repo_MDiesto'...
# ...

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Diesto/IS110_repo_Diesto/PythonEnvi_Diesto
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Diesto/IS110_repo_Diesto/PythonEnvi_Diesto

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Diesto/IS110_repo_Diesto/PythonEnvi_Diesto

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 50.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 30.8 MB/s eta 0:00:00
# ...

# %%
# !virtualenv maria
# Out:
# created virtual environment CPython3.12.12.final.0-64-x86_64 in 7457ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Diesto/IS110_repo_Diesto/PythonEnvi_Diesto/maria, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source maria/bin/activate

# %%
# %%writefile requirements.txt
# pandas
# numpy
# Out:
# Writing requirements.txt

# %%
#install the packages in the requirements.txt
# !maria/bin/pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 18.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 57.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]
# ...

# %%
#requirements.txt has been created or updated
# !maria/bin/pip freeze > requirements.txt

# %%
# !maria/bin/pip list
# Out:
# Package         Version
# --------------- -----------
# numpy           2.4.3
# pandas          3.0.1
# pip             26.0.1
# python-dateutil 2.9.0.post0
# six             1.17.0

# %%
# !cat requirements.txt
# Out:
# numpy==2.4.3
# pandas==3.0.1
# python-dateutil==2.9.0.post0
# six==1.17.0

# %%
ls
# Out:
# chapter2.ipynb  Chapter4.ipynb  maria/
# Chapter3.ipynb  Chapter5.ipynb  requirements.txt

# %% [markdown]
# # **CHAPTER 2 EXERCISES**

# %%
#Write a program to prompt the user for hours and rate per hour to compute gross pay.

hours = input('Enter hours: ')
rate = input("Enter rate: ")
pay = int(hours) * float(rate)
print('Total income: ',pay)
# Out:
# Enter hours: 9
# Enter rate: 8
# Total income:  72.0

# %%
#width//2 width/2.0 height/3  1 + 2 * 5 */
width = 17
height = 12.0

print('width // 2 =',width//2)
print('width / 2 =',width/2)
print('height / 3 =',height/3)
print('1 + 2 * 5 =',1+2*5)
# Out:
# width // 2 = 8
# width / 2 = 8.5
# height / 3 = 4.0
# 1 + 2 * 5 = 11

# %% [markdown]
# # **CHAPTER #2 CHALLENGE**

# %%
#Write a program that uses input to prompt a user for a number and then outputs the square of the number
number = input('Enter a number: ')
square = int(number) * int(number)
print('the square of',number, 'is',square)
# Out:
# Enter a number: 3
# the square of 3 is 9

# %%
cel = float(input("Enter temperature in Celsius: "))
fc = (cel * 9/5) + 32
print(fc)
# Out:
# Enter temperature in Celsius: 0
# 32.0
